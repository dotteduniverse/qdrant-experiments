# %% [markdown]
# # Qdrant Exploration Notebook
#
# Use this notebook to visualize vectors, debug searches, and prototype new ideas.

# %%
import sys
sys.path.append('..')

from src.client_factory import get_client
from src.synthetic_data import generate_points
from config.settings import VECTOR_SIZE

client = get_client(use_memory=True)
print("✅ Client ready!")

# %%
# Generate and inspect data
ids, vectors, payloads = generate_points(100)
print(f"Generated {len(ids)} points")
print(f"Sample payload: {payloads[0]}")
